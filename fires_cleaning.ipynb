# %%
import sqlite3
import pandas as pd
import sqlalchemy
import psycopg2
from sql_functions import get_engine
from sql_functions import get_sql_config
con = sqlite3.connect('data/FPA_FOD_20170508.sqlite')
cursor = con.cursor()

# %%
fires_raw = pd.read_sql_query('SELECT * FROM FIRES', con)

# %%
fires_shape_raw = pd.read_sql_query('SELECT * FROM IDX_FIRES_SHAPE', con)

# %%
fires_raw.head(10)

# %%
fires_shape_raw.head(10)

# %%
fires_shape_raw.rename(columns={"xmin":"x_min", "xmax":"x_max", "ymin":"y_min", "ymax":"y_max"}, inplace=True)

# %%
fires_raw['STATE'].value_counts()

# %%
fires_raw['STATE'].nunique()

# %%
fires_raw.info()

# %%
get_sql_config()

# %%
engine = get_engine()

# %%
table_name = 'fires_shape_raw'
schema = 'capstone_wildfire'

# %%
if engine!=None:
    try:
        fires_raw.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # Use schmea that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None

# %%
if engine!=None:
    try:
        fires_shape_raw.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # Use schmea that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None

# %%
from sql_functions import get_data
get_data(f'SELECT COUNT(*) FROM {schema}.fires_raw')

# %% [markdown]
# ## preparing clean tables

# %%
#creating a dataset to drop unnecessary columns 
fires_clean = pd.read_sql_query('SELECT * FROM FIRES', con)

# %%
#pythonize the column names, lowercase all column titles
fires_clean.columns = fires_clean.columns.str.lower()

# %%
#create a new specific dataframe only with relevant columns
fires_specific = fires_clean[['fod_id', 'source_reporting_unit_name', 'fire_code', 'fire_name', 'fire_year', 'discovery_date', 'discovery_doy', 'discovery_time', 'stat_cause_code', 'stat_cause_descr', 'cont_date', 'cont_doy', 'cont_time', 'fire_size', 'fire_size_class', 'latitude', 'longitude', 'state', 'county', 'shape']]

# %%
#check for new dataframe
fires_specific.head(10)
# Out:
#    fod_id      source_reporting_unit_name fire_code   fire_name  fire_year  \
# 0       1          Plumas National Forest      BJ8K    FOUNTAIN       2005
# 1       2        Eldorado National Forest      AAC0      PIGEON       2004
# 2       3        Eldorado National Forest      A32W       SLACK       2004
# 3       4        Eldorado National Forest      None        DEER       2004
# 4       5        Eldorado National Forest      None    STEVENOT       2004
# 5       6        Eldorado National Forest      None      HIDDEN       2004
# 6       7        Eldorado National Forest      None        FORK       2004
# 7       8  Shasta-Trinity National Forest      BK5X       SLATE       2005
# 8       9  Shasta-Trinity National Forest      BLPQ      SHASTA       2005
# 9      10        Eldorado National Forest      None  TANGLEFOOT       2004
#
#    discovery_date  discovery_doy discovery_time  stat_cause_code  \
# 0       2453403.5             33           1300              9.0
# 1       2453137.5            133           0845              1.0
# 2       2453156.5            152           1921              5.0
# 3       2453184.5            180           1600              1.0
# 4       2453184.5            180           1600              1.0
# 5       2453186.5            182           1800              1.0
# 6       2453187.5            183           1800              1.0
# 7       2453437.5             67           1300              5.0
# 8       2453444.5             74           1200              5.0
# 9       2453187.5            183           1800              1.0
#
#   stat_cause_descr  cont_date  cont_doy cont_time  fire_size fire_size_class  \
# 0    Miscellaneous  2453403.5      33.0      1730       0.10               A
# 1        Lightning  2453137.5     133.0      1530       0.25               A
# 2   Debris Burning  2453156.5     152.0      2024       0.10               A
# 3        Lightning  2453189.5     185.0      1400       0.10               A
# 4        Lightning  2453189.5     185.0      1200       0.10               A
# 5        Lightning  2453187.5     183.0      1600       0.10               A
# 6        Lightning  2453188.5     184.0      1400       0.10               A
# 7   Debris Burning  2453437.5      67.0      1600       0.80               B
# 8   Debris Burning  2453444.5      74.0      1700       1.00               B
# 9        Lightning  2453188.5     184.0      1800       0.10               A
#
#     latitude   longitude state county  \
# 0  40.036944 -121.005833    CA     63
# 1  38.933056 -120.404444    CA     61
# 2  38.984167 -120.735556    CA     17
# 3  38.559167 -119.913333    CA      3
# 4  38.559167 -119.933056    CA      3
# 5  38.635278 -120.103611    CA      5
# 6  38.688333 -120.153333    CA     17
# 7  40.968056 -122.433889    CA   None
# 8  41.233611 -122.283333    CA   None
# 9  38.548333 -120.149167    CA      5
#
#                                                shape
# 0  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_@^\xc0...
# 1  b'\x00\x01\xad\x10\x00\x00T\xb6\xeej\xe2\x19^\...
# 2  b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13/^\...
# 3  b'\x00\x01\xad\x10\x00\x00\x94\xac\xa3\rt\xfa]...
# 4  b'\x00\x01\xad\x10\x00\x00@\xe3\xaa.\xb7\xfb]\...
# 5  b'\x00\x01\xad\x10\x00\x00\xf0<~\x90\xa1\x06^\...
# 6  b'\x00\x01\xad\x10\x00\x00$o\x996\xd0\t^\xc0h\...
# 7  b'\x00\x01\xad\x10\x00\x00t)\xe8\xd5\xc4\x9b^\...
# 8  b'\x00\x01\xad\x10\x00\x00\xdc\x8d\x1e""\x92^\...
# 9  b'\x00\x01\xad\x10\x00\x00dS\\\xf2\x8b\t^\xc0\...

# %%
#renaming columns for better understanding
fires_specific.rename(columns={"fod_id":"unique_id", "fire_code":"gov_firecode", "stat_cause_code":"cause_code", "stat_cause_descr":"cause_descr", "cont_date":"control_date", "cont_doy":"control_doy", "cont_time":"control_time", "shape":"shape_hex"}, inplace=True)
# Out:
# /var/folders/71/74jym8nn07z_r531l25_2hd00000gn/T/ipykernel_9851/2377257351.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_specific.rename(columns={"fod_id":"unique_id", "fire_code":"gov_firecode", "stat_cause_code":"cause_code", "stat_cause_descr":"cause_descr", "cont_date":"control_date", "cont_doy":"control_doy", "cont_time":"control_time", "shape":"shape_hex"}, inplace=True)

# %%
#checking result
print(fires_specific.columns)
# Out:
# Index(['unique_id', 'source_reporting_unit_name', 'gov_firecode', 'fire_name',
#        'fire_year', 'discovery_date', 'discovery_doy', 'discovery_time',
#        'cause_code', 'cause_descr', 'control_date', 'control_doy',
#        'control_time', 'fire_size', 'fire_size_class', 'latitude', 'longitude',
#        'state', 'county', 'shape_hex'],
#       dtype='object')

# %%
#converting Julian calendar date from discovery_date and control_date to Gregorian calendar
epoch = pd.to_datetime(0, unit='s').to_julian_date()
fires_specific['discovery_date'] = pd.to_datetime(fires_specific['discovery_date'] - epoch, unit='D')
fires_specific['control_date'] = pd.to_datetime(fires_specific['control_date'] - epoch, unit='D')
# Out:
# /var/folders/71/74jym8nn07z_r531l25_2hd00000gn/T/ipykernel_9851/2647599007.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_specific['discovery_date'] = pd.to_datetime(fires_specific['discovery_date'] - epoch, unit='D')
# /var/folders/71/74jym8nn07z_r531l25_2hd00000gn/T/ipykernel_9851/2647599007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_specific['control_date'] = pd.to_datetime(fires_specific['control_date'] - epoch, unit='D')

# %%
fires_specific.head(10)
# Out:
#    unique_id      source_reporting_unit_name gov_firecode   fire_name  \
# 0          1          Plumas National Forest         BJ8K    FOUNTAIN
# 1          2        Eldorado National Forest         AAC0      PIGEON
# 2          3        Eldorado National Forest         A32W       SLACK
# 3          4        Eldorado National Forest         None        DEER
# 4          5        Eldorado National Forest         None    STEVENOT
# 5          6        Eldorado National Forest         None      HIDDEN
# 6          7        Eldorado National Forest         None        FORK
# 7          8  Shasta-Trinity National Forest         BK5X       SLATE
# 8          9  Shasta-Trinity National Forest         BLPQ      SHASTA
# 9         10        Eldorado National Forest         None  TANGLEFOOT
#
#    fire_year discovery_date  discovery_doy discovery_time  cause_code  \
# 0       2005     2005-02-02             33           1300         9.0
# 1       2004     2004-05-12            133           0845         1.0
# 2       2004     2004-05-31            152           1921         5.0
# 3       2004     2004-06-28            180           1600         1.0
# 4       2004     2004-06-28            180           1600         1.0
# 5       2004     2004-06-30            182           1800         1.0
# 6       2004     2004-07-01            183           1800         1.0
# 7       2005     2005-03-08             67           1300         5.0
# 8       2005     2005-03-15             74           1200         5.0
# 9       2004     2004-07-01            183           1800         1.0
#
#       cause_descr control_date  control_doy control_time  fire_size  \
# 0   Miscellaneous   2005-02-02         33.0         1730       0.10
# 1       Lightning   2004-05-12        133.0         1530       0.25
# 2  Debris Burning   2004-05-31        152.0         2024       0.10
# 3       Lightning   2004-07-03        185.0         1400       0.10
# 4       Lightning   2004-07-03        185.0         1200       0.10
# 5       Lightning   2004-07-01        183.0         1600       0.10
# 6       Lightning   2004-07-02        184.0         1400       0.10
# 7  Debris Burning   2005-03-08         67.0         1600       0.80
# 8  Debris Burning   2005-03-15         74.0         1700       1.00
# 9       Lightning   2004-07-02        184.0         1800       0.10
#
#   fire_size_class   latitude   longitude state county  \
# 0               A  40.036944 -121.005833    CA     63
# 1               A  38.933056 -120.404444    CA     61
# 2               A  38.984167 -120.735556    CA     17
# 3               A  38.559167 -119.913333    CA      3
# 4               A  38.559167 -119.933056    CA      3
# 5               A  38.635278 -120.103611    CA      5
# 6               A  38.688333 -120.153333    CA     17
# 7               B  40.968056 -122.433889    CA   None
# 8               B  41.233611 -122.283333    CA   None
# 9               A  38.548333 -120.149167    CA      5
#
#                                            shape_hex
# 0  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_@^\xc0...
# 1  b'\x00\x01\xad\x10\x00\x00T\xb6\xeej\xe2\x19^\...
# 2  b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13/^\...
# 3  b'\x00\x01\xad\x10\x00\x00\x94\xac\xa3\rt\xfa]...
# 4  b'\x00\x01\xad\x10\x00\x00@\xe3\xaa.\xb7\xfb]\...
# 5  b'\x00\x01\xad\x10\x00\x00\xf0<~\x90\xa1\x06^\...
# 6  b'\x00\x01\xad\x10\x00\x00$o\x996\xd0\t^\xc0h\...
# 7  b'\x00\x01\xad\x10\x00\x00t)\xe8\xd5\xc4\x9b^\...
# 8  b'\x00\x01\xad\x10\x00\x00\xdc\x8d\x1e""\x92^\...
# 9  b'\x00\x01\xad\x10\x00\x00dS\\\xf2\x8b\t^\xc0\...

# %%
#changing discovery_time and control_time into readable time
fires_specific['discovery_time'] = pd.to_datetime(fires_specific.discovery_time, format='%H%M').dt.time
fires_specific['control_time'] = pd.to_datetime(fires_specific.control_time, format='%H%M').dt.time
# Out:
# /var/folders/71/74jym8nn07z_r531l25_2hd00000gn/T/ipykernel_9851/4224906157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_specific['discovery_time'] = pd.to_datetime(fires_specific.discovery_time, format='%H%M').dt.time
# /var/folders/71/74jym8nn07z_r531l25_2hd00000gn/T/ipykernel_9851/4224906157.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_specific['control_time'] = pd.to_datetime(fires_specific.control_time, format='%H%M').dt.time

# %%
#converting control_doy into int result in error as there are null values
fires_specific['control_doy'] = fires_specific['control_doy'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /Users/johannesschepelmann/Desktop/Projects/Capstone_Project/fires_cleaning.ipynb Zelle 26 line 2
#       <a href='vscode-notebook-cell:/Users/johannesschepelmann/Desktop/Projects/Capstone_Project/fires_cleaning.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> #converting control_doy into int result in error as there are null values
# ----> <a href='vscode-notebook-cell:/Users/johannesschepelmann/Desktop/Projects/Capstone_Project/fires_cleaning.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> fires_specific['control_doy'] = fires_specific['control_doy'].astype(int)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/internals/blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:105, in _astype_nansafe(arr, dtype, copy, skipna)
#     100     return lib.ensure_string_array(
#     101         arr, skipna=skipna, convert_na_value=False
#     102     ).reshape(shape)
#     104 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 105     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     107 elif is_object_dtype(arr.dtype):
#     108     # if we have a datetime/timedelta array of objects
#     109     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     111     if is_datetime64_dtype(dtype):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:150, in _astype_float_to_int_nansafe(values, dtype, copy)
#     146 """
#     147 astype with a check preventing converting NaN to an meaningless integer value.
#     148 """
#     149 if not np.isfinite(values).all():
# --> 150     raise IntCastingNaNError(
#     151         "Cannot convert non-finite values (NA or inf) to integer"
#     152     )
#     153 if dtype.kind == "u":
#     154     # GH#45151
#     155     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
#converting cause_code into int
fires_specific['cause_code'] = fires_specific['cause_code'].astype(int)
# Out:
# /var/folders/71/74jym8nn07z_r531l25_2hd00000gn/T/ipykernel_9851/3867861528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_specific['cause_code'] = fires_specific['cause_code'].astype(int)

# %%
#pushing final table into SQL database
if engine!=None:
    try:
        fires_specific.to_sql(name='fires_data', # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # Use schmea that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The fires_data table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The fires_data table was imported successfully.
